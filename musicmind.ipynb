# %%
![title](https://www.dropbox.com/s/astm73a8s2m7a6e/iphone-app-60pt%402x.png.png?dl=0)
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `https://www.dropbox.com/s/astm73a8s2m7a6e/iphone-app-60pt%402x.png.png?dl=0'
# /bin/sh: -c: line 0: `[title](https://www.dropbox.com/s/astm73a8s2m7a6e/iphone-app-60pt%402x.png.png?dl=0)'

# %% [markdown]
# # MusicMind Database -
#
# ### A survey of popular music metadata and lyrics

# %%
import pprint
from pymongo.mongo_client import MongoClient


URI = "mongodb://MusicMind:6jlewvwvuBVqJls4@features-shard-00-00-edm1t.mongodb.net:27017,features-shard-00-01-edm1t.mongodb.net:27017,features-shard-00-02-edm1t.mongodb.net:27017/features?ssl=true&replicaSet=features-shard-0&authSource=admin"
client = MongoClient(URI)
db = client['MetaMind']
posts = db.posts



collection = posts.find_one({'artist': 'Drake', 'track': 'One Dance'})

pprint.pprint(collection)
# Out:
# {'_id': ObjectId('58c1a1b339affd3e7c22a66b'),
#  'album': 'Views',
#  'artist': 'Drake',
#  'artist_popularity': 96,
#  'explicit': False,
#  'feature': {'acousticness': 0.00902,
#              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12VWzyPDBCc8fqeWCAfNwR',
#              'danceability': 0.785,
#              'duration_ms': 173987,
#              'energy': 0.617,
#              'id': '12VWzyPDBCc8fqeWCAfNwR',
#              'instrumentalness': 0.00246,
#              'key': 1,
#              'liveness': 0.351,
#              'loudness': -5.871,
#              'mode': 1,
#              'speechiness': 0.0522,
#              'tempo': 103.981,
#              'time_signature': 4,
#              'track_href': 'https://api.spotify.com/v1/tracks/12VWzyPDBCc8fqeWCAfNwR',
#              'type': 'audio_features',
#              'uri': 'spotify:track:12VWzyPDBCc8fqeWCAfNwR',
#              'valence': 0.378},
#  'featured_artists': ['WizKid', 'Kyla'],
#  'followers': 8777552,
#  'genres': ['canadian pop', 'hip hop', 'pop rap', 'rap'],
#  'lyrics': [['Drake – One Dance Lyrics | Genius Lyrics',
#              '\n'
#              '\n'
#              '[Intro: Kyla]\n'
#              'Baby, I like your style\n'
#              '\n'
#              '[Verse 1: Drake]\n'
#              'Grips on your waist\n'
#              'Front way, back way\n'
#              "You know that I don't play\n"
#              'Streets not safe\n'
#              'But I never run away\n'
#              "Even when I'm away\n"
#              "Oti, oti, there's never much love when we go OT\n"
#              'I pray to make it back in one piece\n'
#              'I pray, I pray\n'
#              '\n'
#              '[Hook: Drake]\n'
#              "That's why I need a one dance\n"
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              'I need a one dance\n'
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              '\n'
#              '[Bridge: Kyla]\n'
#              'Baby, I like your style\n'
#              '\n'
#              '[Verse 2: Drake]\n'
#              'Strength and guidance\n'
#              "All that I'm wishing for my friends\n"
#              'Nobody makes it from my ends\n'
#              'I had to bust up the silence\n'
#              'You know you gotta stick by me\n'
#              'Soon as you see the text, reply me\n'
#              "I don't wanna spend time fighting\n"
#              "We've got no time\n"
#              '\n'
#              '[Hook: Drake]\n'
#              "And that's why I need a one dance\n"
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              'I need a one dance\n'
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              '\n'
#              '[Break: Wizkid]\n'
#              'Got a pretty girl and she love me long time\n'
#              'Wine it, wine it, very long time\n'
#              'Oh yeah, very long time\n'
#              'Back up, back up, back up and wine it\n'
#              'Back up, back up and wine it, girl\n'
#              'Back up, back up, back up and wine it\n'
#              'Oh yeah, very long time\n'
#              'Back, up, back up and wine it, girl\n'
#              '\n'
#              '[Bridge: Kyla + Wizkid]\n'
#              'Tell me\n'
#              'I need to know, where do you wanna go?\n'
#              "Cause if you're down, I'll take it slow\n"
#              'Make you lose control\n'
#              'Where, where, where\n'
#              'Where, where, where, where\n'
#              'Oh yeah, very long time\n'
#              'Where, where, where\n'
#              'Back, up, back up and wine it, girl\n'
#              'Where, where, where, where\n'
#              "Cause if you're down\n"
#              'Back up, back up and\n'
#              "Cause if you're down\n"
#              'Back up, back up and\n'
#              "Cause if you're down\n"
#              'Back up, back up and\n'
#              '\n'
#              '[Hook: Drake]\n'
#              'I need a one dance\n'
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              'I need a one dance\n'
#              'Got a Hennessy in my hand\n'
#              "One more time 'fore I go\n"
#              'Higher powers taking a hold on me\n'
#              '\n'],
#             None],
#  'popularity': 80,
#  'track': 'One Dance'}

# %%
total_tracks = posts.count()

print(total_tracks, "total tracks")
# Out:
# 6941 total tracks

# %%
import pandas as pd

df =pd.DataFrame(list(posts.find()))
df.head()
# Out:
#                         _id                             album  \
# 0  58c1a18d39affd3e7c22a668                         Fake Love
# 1  58c1a19c39affd3e7c22a669  The Return of East Atlanta Santa
# 2  58c1a1a739affd3e7c22a66a              PARTYNEXTDOOR 3 (P3)
# 3  58c1a1b339affd3e7c22a66b                             Views
# 4  58c1a1c139affd3e7c22a66c                          Sneakin’
#
#    album_popularity         artist  artist_popularity explicit  \
# 0               NaN          Drake                 96     True
# 1               NaN     Gucci Mane                 86     True
# 2               NaN  PARTYNEXTDOOR                 83     True
# 3               NaN          Drake                 96    False
# 4               NaN          Drake                 96     True
#
#                                              feature featured_artists  \
# 0  {'track_href': 'https://api.spotify.com/v1/tra...               []
# 1  {'track_href': 'https://api.spotify.com/v1/tra...    [Drake, Drak]
# 2  {'track_href': 'https://api.spotify.com/v1/tra...    [Drake, Drak]
# 3  {'track_href': 'https://api.spotify.com/v1/tra...   [WizKid, Kyla]
# 4  {'track_href': 'https://api.spotify.com/v1/tra...      [21 Savage]
#
#    followers                                             genres  \
# 0  8777532.0              [canadian pop, hip hop, pop rap, rap]
# 1   631174.0  [dirty south rap, dwn trap, pop rap, rap, sout...
# 2   586138.0  [dance pop, dwn trap, indie r&b, pop, pop rap,...
# 3  8777552.0              [canadian pop, hip hop, pop rap, rap]
# 4  8777553.0              [canadian pop, hip hop, pop rap, rap]
#
#                                               lyrics  popularity  \
# 0  [[Drake – Fake Love Lyrics | Genius Lyrics, \n...          86
# 1  [[Gucci Mane – Both Lyrics | Genius Lyrics, \n...          80
# 2  [[PARTYNEXTDOOR – Come and See Me Lyrics | Gen...          76
# 3  [[Drake – One Dance Lyrics | Genius Lyrics, \n...          80
# 4  [[Drake – Sneakin' Lyrics | Genius Lyrics, \n\...          79
#
#                            track
# 0                      Fake Love
# 1             Both (feat. Drake)
# 2  Come and See Me (feat. Drake)
# 3                      One Dance
# 4                       Sneakin’

# %%
print(len(df['artist'].unique()), "unique artists")
# Out:
# 832 unique artists

# %%
print(len(df['album'].unique()), "unique albums")
# Out:
# 2028 unique albums

# %%
h_count = 0
for record in df['genres']:
    if 'hip hop' in record:
        h_count+= 1
            
print(h_count, "total hiphop songs")
# Out:
# 2328 total hiphop songs

# %%
features = df['feature']

features.count()
# Out:
# 6942

# %%
lyrics = df['lyrics']

lyrics.count()
# Out:
# 6890

# %%
features_lyrics = pd.DataFrame([df['feature'], df['lyrics']])

# %%
duration = features_lyrics[0]['feature']['duration_ms']

# %%
lyric_string = ''.join(features_lyrics[0]['lyrics'][0])
line_list = lyric_string.split("""\n""")
# Out:
# 'Drake – Fake Love Lyrics | Genius Lyrics[Hook]I\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my faceI\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my face[Verse 1]Somethin\' ain\'t right when we talkin\'Somethin\' ain\'t right when we talkin\'Look like you hidin\' your problemsReally you never was solidNo, you can\'t "son" meYou won\'t never get to run meJust when shit look out of reachI reach back like one, threeLike one, three, yeah[Pre-Hook]That\'s when they smile in my faceWhole time they wanna take my placeWhole time they wanna take my placeWhole time they wanna take my placeYeah, I know they wanna take my placeI can tell that love is fakeI don\'t trust a word you sayHow you wanna clique up after your mistakes?Look you in the face, and it\'s just not the same[Hook]I\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my faceI\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my face[Verse 2]Yeah, straight up to my face, tryna play it safeVibe switch like night and dayI can see it, like, right awayI came up, you changed upI caught that whole playSince, things never been the same[Pre-Hook]That\'s when they smile in my faceWhole time they wanna take my placeWhole time they wanna take my placeWhole time they wanna take my placeYeah, I know they wanna take my placeI can tell that love is fake (I can tell that love is fake)I don\'t trust a word you say (I don\'t trust a word)How you wanna clique up after your mistakes?(That\'s just what I heard)Look you in the face, and it\'s just not the same[Hook]I\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my faceI\'ve been down so long, it look like up to meThey look up to meI got fake people showin\' fake love to meStraight up to my face, straight up to my face[Outro]Skrrt'

# %%
import numpy as np
import string

word_list = []
for line in line_list:
    if line !='' and "|" not in line and "[" not in line:
        words = line.split(' ')
        word_list.append(words)

word_count = 0
char_count = 0
word_lengths = []
bar_lengths = []
words = []
word_groups = []
for word_group in word_list:
    word_count += len(word_group)
    bar_lengths.append(len(word_group))
    word_groups.append(word_group)
    for i, word in enumerate(word_group):
        word_lengths.append(len(word))
        words.append(word)
        for letter in word:
            if letter not in string.ascii_letters:
                words.replace()
            char_count += 1

print("Bar count: ", len(line_list))
print("word count: ", word_count)
print("bars per minute: ", round(len(line_list)/duration*1000*60))
print("words per minute: ", round(word_count/duration*1000*60))
print("character count: ", char_count)
print("Average word lengths", round(np.average(word_lengths), 1))
print("Average words per bar", round(np.average(bar_lengths), 1))
# Out:
# Bar count:  78
# word count:  458
# bars per minute:  23
# words per minute:  132
# character count:  1688
# Average word lengths 3.7
# Average words per bar 7.8

# %%
timing = {}
word_time_elapsed = 0
for word in words:
    word_time_elapsed += duration/word_count
    timing[round(word_time_elapsed)] = word
    
timing
# Out:
# {454: "I've",
#  907: 'been',
#  1361: 'down',
#  1815: 'so',
#  2269: 'long,',
#  2722: 'it',
#  3176: 'look',
#  3630: 'like',
#  4084: 'up',
#  4537: 'to',
#  4991: 'me',
#  5445: 'They',
#  5899: 'look',
#  6352: 'up',
#  6806: 'to',
#  7260: 'me',
#  7714: 'I',
#  8167: 'got',
#  8621: 'fake',
#  9075: 'people',
#  9529: "showin'",
#  9982: 'fake',
#  10436: 'love',
#  10890: 'to',
#  11344: 'me',
#  11797: 'Straight',
#  12251: 'up',
#  12705: 'to',
#  13158: 'my',
#  13612: 'face,',
#  14066: 'straight',
#  14520: 'up',
#  14973: 'to',
#  15427: 'my',
#  15881: 'face',
#  16335: "I've",
#  16788: 'been',
#  17242: 'down',
#  17696: 'so',
#  18150: 'long,',
#  18603: 'it',
#  19057: 'look',
#  19511: 'like',
#  19965: 'up',
#  20418: 'to',
#  20872: 'me',
#  21326: 'They',
#  21780: 'look',
#  22233: 'up',
#  22687: 'to',
#  23141: 'me',
#  23594: 'I',
#  24048: 'got',
#  24502: 'fake',
#  24956: 'people',
#  25409: "showin'",
#  25863: 'fake',
#  26317: 'love',
#  26771: 'to',
#  27224: 'me',
#  27678: 'Straight',
#  28132: 'up',
#  28586: 'to',
#  29039: 'my',
#  29493: 'face,',
#  29947: 'straight',
#  30401: 'up',
#  30854: 'to',
#  31308: 'my',
#  31762: 'face',
#  32216: "Somethin'",
#  32669: "ain't",
#  33123: 'right',
#  33577: 'when',
#  34031: 'we',
#  34484: "talkin'",
#  34938: "Somethin'",
#  35392: "ain't",
#  35845: 'right',
#  36299: 'when',
#  36753: 'we',
#  37207: "talkin'",
#  37660: 'Look',
#  38114: 'like',
#  38568: 'you',
#  39022: "hidin'",
#  39475: 'your',
#  39929: 'problems',
#  40383: 'Really',
#  40837: 'you',
#  41290: 'never',
#  41744: 'was',
#  42198: 'solid',
#  42652: 'No,',
#  43105: 'you',
#  43559: "can't",
#  44013: '"son"',
#  44467: 'me',
#  44920: 'You',
#  45374: "won't",
#  45828: 'never',
#  46281: 'get',
#  46735: 'to',
#  47189: 'run',
#  47643: 'me',
#  48096: 'Just',
#  48550: 'when',
#  49004: 'shit',
#  49458: 'look',
#  49911: 'out',
#  50365: 'of',
#  50819: 'reach',
#  51273: 'I',
#  51726: 'reach',
#  52180: 'back',
#  52634: 'like',
#  53088: 'one,',
#  53541: 'three',
#  53995: 'Like',
#  54449: 'one,',
#  54903: 'three,',
#  55356: 'yeah',
#  55810: "That's",
#  56264: 'when',
#  56718: 'they',
#  57171: 'smile',
#  57625: 'in',
#  58079: 'my',
#  58532: 'face',
#  58986: 'Whole',
#  59440: 'time',
#  59894: 'they',
#  60347: 'wanna',
#  60801: 'take',
#  61255: 'my',
#  61709: 'place',
#  62162: 'Whole',
#  62616: 'time',
#  63070: 'they',
#  63524: 'wanna',
#  63977: 'take',
#  64431: 'my',
#  64885: 'place',
#  65339: 'Whole',
#  65792: 'time',
#  66246: 'they',
#  66700: 'wanna',
#  67154: 'take',
#  67607: 'my',
#  68061: 'place',
#  68515: 'Yeah,',
#  68969: 'I',
#  69422: 'know',
#  69876: 'they',
#  70330: 'wanna',
#  70783: 'take',
#  71237: 'my',
#  71691: 'place',
#  72145: 'I',
#  72598: 'can',
#  73052: 'tell',
#  73506: 'that',
#  73960: 'love',
#  74413: 'is',
#  74867: 'fake',
#  75321: 'I',
#  75775: "don't",
#  76228: 'trust',
#  76682: 'a',
#  77136: 'word',
#  77590: 'you',
#  78043: 'say',
#  78497: 'How',
#  78951: 'you',
#  79405: 'wanna',
#  79858: 'clique',
#  80312: 'up',
#  80766: 'after',
#  81219: 'your',
#  81673: 'mistakes?',
#  82127: 'Look',
#  82581: 'you',
#  83034: 'in',
#  83488: 'the',
#  83942: 'face,',
#  84396: 'and',
#  84849: "it's",
#  85303: 'just',
#  85757: 'not',
#  86211: 'the',
#  86664: 'same',
#  87118: "I've",
#  87572: 'been',
#  88026: 'down',
#  88479: 'so',
#  88933: 'long,',
#  89387: 'it',
#  89841: 'look',
#  90294: 'like',
#  90748: 'up',
#  91202: 'to',
#  91656: 'me',
#  92109: 'They',
#  92563: 'look',
#  93017: 'up',
#  93470: 'to',
#  93924: 'me',
#  94378: 'I',
#  94832: 'got',
#  95285: 'fake',
#  95739: 'people',
#  96193: "showin'",
#  96647: 'fake',
#  97100: 'love',
#  97554: 'to',
#  98008: 'me',
#  98462: 'Straight',
#  98915: 'up',
#  99369: 'to',
#  99823: 'my',
#  100277: 'face,',
#  100730: 'straight',
#  101184: 'up',
#  101638: 'to',
#  102092: 'my',
#  102545: 'face',
#  102999: "I've",
#  103453: 'been',
#  103907: 'down',
#  104360: 'so',
#  104814: 'long,',
#  105268: 'it',
#  105721: 'look',
#  106175: 'like',
#  106629: 'up',
#  107083: 'to',
#  107536: 'me',
#  107990: 'They',
#  108444: 'look',
#  108898: 'up',
#  109351: 'to',
#  109805: 'me',
#  110259: 'I',
#  110713: 'got',
#  111166: 'fake',
#  111620: 'people',
#  112074: "showin'",
#  112528: 'fake',
#  112981: 'love',
#  113435: 'to',
#  113889: 'me',
#  114343: 'Straight',
#  114796: 'up',
#  115250: 'to',
#  115704: 'my',
#  116157: 'face,',
#  116611: 'straight',
#  117065: 'up',
#  117519: 'to',
#  117972: 'my',
#  118426: 'face',
#  118880: 'Yeah,',
#  119334: 'straight',
#  119787: 'up',
#  120241: 'to',
#  120695: 'my',
#  121149: 'face,',
#  121602: 'tryna',
#  122056: 'play',
#  122510: 'it',
#  122964: 'safe',
#  123417: 'Vibe',
#  123871: 'switch',
#  124325: 'like',
#  124779: 'night',
#  125232: 'and',
#  125686: 'day',
#  126140: 'I',
#  126594: 'can',
#  127047: 'see',
#  127501: 'it,',
#  127955: 'like,',
#  128408: 'right',
#  128862: 'away',
#  129316: 'I',
#  129770: 'came',
#  130223: 'up,',
#  130677: 'you',
#  131131: 'changed',
#  131585: 'up',
#  132038: 'I',
#  132492: 'caught',
#  132946: 'that',
#  133400: 'whole',
#  133853: 'play',
#  134307: 'Since,',
#  134761: 'things',
#  135215: 'never',
#  135668: 'been',
#  136122: 'the',
#  136576: 'same',
#  137030: "That's",
#  137483: 'when',
#  137937: 'they',
#  138391: 'smile',
#  138844: 'in',
#  139298: 'my',
#  139752: 'face',
#  140206: 'Whole',
#  140659: 'time',
#  141113: 'they',
#  141567: 'wanna',
#  142021: 'take',
#  142474: 'my',
#  142928: 'place',
#  143382: 'Whole',
#  143836: 'time',
#  144289: 'they',
#  144743: 'wanna',
#  145197: 'take',
#  145651: 'my',
#  146104: 'place',
#  146558: 'Whole',
#  147012: 'time',
#  147466: 'they',
#  147919: 'wanna',
#  148373: 'take',
#  148827: 'my',
#  149281: 'place',
#  149734: 'Yeah,',
#  150188: 'I',
#  150642: 'know',
#  151095: 'they',
#  151549: 'wanna',
#  152003: 'take',
#  152457: 'my',
#  152910: 'place',
#  153364: 'I',
#  153818: 'can',
#  154272: 'tell',
#  154725: 'that',
#  155179: 'love',
#  155633: 'is',
#  156087: 'fake',
#  156540: '(I',
#  156994: 'can',
#  157448: 'tell',
#  157902: 'that',
#  158355: 'love',
#  158809: 'is',
#  159263: 'fake)',
#  159717: 'I',
#  160170: "don't",
#  160624: 'trust',
#  161078: 'a',
#  161532: 'word',
#  161985: 'you',
#  162439: 'say',
#  162893: '(I',
#  163346: "don't",
#  163800: 'trust',
#  164254: 'a',
#  164708: 'word)',
#  165161: 'How',
#  165615: 'you',
#  166069: 'wanna',
#  166523: 'clique',
#  166976: 'up',
#  167430: 'after',
#  167884: 'your',
#  168338: 'mistakes?',
#  168791: "(That's",
#  169245: 'just',
#  169699: 'what',
#  170153: 'I',
#  170606: 'heard)',
#  171060: 'Look',
#  171514: 'you',
#  171968: 'in',
#  172421: 'the',
#  172875: 'face,',
#  173329: 'and',
#  173782: "it's",
#  174236: 'just',
#  174690: 'not',
#  175144: 'the',
#  175597: 'same',
#  176051: "I've",
#  176505: 'been',
#  176959: 'down',
#  177412: 'so',
#  177866: 'long,',
#  178320: 'it',
#  178774: 'look',
#  179227: 'like',
#  179681: 'up',
#  180135: 'to',
#  180589: 'me',
#  181042: 'They',
#  181496: 'look',
#  181950: 'up',
#  182404: 'to',
#  182857: 'me',
#  183311: 'I',
#  183765: 'got',
#  184219: 'fake',
#  184672: 'people',
#  185126: "showin'",
#  185580: 'fake',
#  186033: 'love',
#  186487: 'to',
#  186941: 'me',
#  187395: 'Straight',
#  187848: 'up',
#  188302: 'to',
#  188756: 'my',
#  189210: 'face,',
#  189663: 'straight',
#  190117: 'up',
#  190571: 'to',
#  191025: 'my',
#  191478: 'face',
#  191932: "I've",
#  192386: 'been',
#  192840: 'down',
#  193293: 'so',
#  193747: 'long,',
#  194201: 'it',
#  194655: 'look',
#  195108: 'like',
#  195562: 'up',
#  196016: 'to',
#  196469: 'me',
#  196923: 'They',
#  197377: 'look',
#  197831: 'up',
#  198284: 'to',
#  198738: 'me',
#  199192: 'I',
#  199646: 'got',
#  200099: 'fake',
#  200553: 'people',
#  201007: "showin'",
#  201461: 'fake',
#  201914: 'love',
#  202368: 'to',
#  202822: 'me',
#  203276: 'Straight',
#  203729: 'up',
#  204183: 'to',
#  204637: 'my',
#  205091: 'face,',
#  205544: 'straight',
#  205998: 'up',
#  206452: 'to',
#  206906: 'my',
#  207359: 'face',
#  207813: 'Skrrt'}

# %%
timing_bars = {}
elapsed = 0
for line in word_groups:
    elapsed += duration/len(word_groups)
    timing_bars[round(elapsed)] = line
    
timing_bars
# Out:
# {3522: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  7045: ['They', 'look', 'up', 'to', 'me'],
#  10567: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  14089: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  17611: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  21134: ['They', 'look', 'up', 'to', 'me'],
#  24656: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  28178: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  31700: ["Somethin'", "ain't", 'right', 'when', 'we', "talkin'"],
#  35223: ["Somethin'", "ain't", 'right', 'when', 'we', "talkin'"],
#  38745: ['Look', 'like', 'you', "hidin'", 'your', 'problems'],
#  42267: ['Really', 'you', 'never', 'was', 'solid'],
#  45789: ['No,', 'you', "can't", '"son"', 'me'],
#  49312: ['You', "won't", 'never', 'get', 'to', 'run', 'me'],
#  52834: ['Just', 'when', 'shit', 'look', 'out', 'of', 'reach'],
#  56356: ['I', 'reach', 'back', 'like', 'one,', 'three'],
#  59878: ['Like', 'one,', 'three,', 'yeah'],
#  63401: ["That's", 'when', 'they', 'smile', 'in', 'my', 'face'],
#  66923: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  70445: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  73967: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  77490: ['Yeah,', 'I', 'know', 'they', 'wanna', 'take', 'my', 'place'],
#  81012: ['I', 'can', 'tell', 'that', 'love', 'is', 'fake'],
#  84534: ['I', "don't", 'trust', 'a', 'word', 'you', 'say'],
#  88056: ['How', 'you', 'wanna', 'clique', 'up', 'after', 'your', 'mistakes?'],
#  91579: ['Look',
#   'you',
#   'in',
#   'the',
#   'face,',
#   'and',
#   "it's",
#   'just',
#   'not',
#   'the',
#   'same'],
#  95101: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  98623: ['They', 'look', 'up', 'to', 'me'],
#  102145: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  105668: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  109190: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  112712: ['They', 'look', 'up', 'to', 'me'],
#  116234: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  119757: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  123279: ['Yeah,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'tryna',
#   'play',
#   'it',
#   'safe'],
#  126801: ['Vibe', 'switch', 'like', 'night', 'and', 'day'],
#  130323: ['I', 'can', 'see', 'it,', 'like,', 'right', 'away'],
#  133846: ['I', 'came', 'up,', 'you', 'changed', 'up'],
#  137368: ['I', 'caught', 'that', 'whole', 'play'],
#  140890: ['Since,', 'things', 'never', 'been', 'the', 'same'],
#  144412: ["That's", 'when', 'they', 'smile', 'in', 'my', 'face'],
#  147935: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  151457: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  154979: ['Whole', 'time', 'they', 'wanna', 'take', 'my', 'place'],
#  158501: ['Yeah,', 'I', 'know', 'they', 'wanna', 'take', 'my', 'place'],
#  162024: ['I',
#   'can',
#   'tell',
#   'that',
#   'love',
#   'is',
#   'fake',
#   '(I',
#   'can',
#   'tell',
#   'that',
#   'love',
#   'is',
#   'fake)'],
#  165546: ['I',
#   "don't",
#   'trust',
#   'a',
#   'word',
#   'you',
#   'say',
#   '(I',
#   "don't",
#   'trust',
#   'a',
#   'word)'],
#  169068: ['How', 'you', 'wanna', 'clique', 'up', 'after', 'your', 'mistakes?'],
#  172590: ["(That's", 'just', 'what', 'I', 'heard)'],
#  176113: ['Look',
#   'you',
#   'in',
#   'the',
#   'face,',
#   'and',
#   "it's",
#   'just',
#   'not',
#   'the',
#   'same'],
#  179635: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  183157: ['They', 'look', 'up', 'to', 'me'],
#  186679: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  190202: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  193724: ["I've",
#   'been',
#   'down',
#   'so',
#   'long,',
#   'it',
#   'look',
#   'like',
#   'up',
#   'to',
#   'me'],
#  197246: ['They', 'look', 'up', 'to', 'me'],
#  200768: ['I', 'got', 'fake', 'people', "showin'", 'fake', 'love', 'to', 'me'],
#  204291: ['Straight',
#   'up',
#   'to',
#   'my',
#   'face,',
#   'straight',
#   'up',
#   'to',
#   'my',
#   'face'],
#  207813: ['Skrrt']}

# %%
timed_bars = pd.DataFrame([timing_bars])
timed_bars
# Out:
#                                               3522    \
# 0  [I've, been, down, so, long,, it, look, like, ...
#
#                      7045    \
# 0  [They, look, up, to, me]
#
#                                               10567   \
# 0  [I, got, fake, people, showin', fake, love, to...
#
#                                               14089   \
# 0  [Straight, up, to, my, face,, straight, up, to...
#
#                                               17611   \
# 0  [I've, been, down, so, long,, it, look, like, ...
#
#                      21134   \
# 0  [They, look, up, to, me]
#
#                                               24656   \
# 0  [I, got, fake, people, showin', fake, love, to...
#
#                                               28178   \
# 0  [Straight, up, to, my, face,, straight, up, to...
#
#                                          31700   \
# 0  [Somethin', ain't, right, when, we, talkin']
#
#                                          35223    ...     \
# 0  [Somethin', ain't, right, when, we, talkin']   ...
#
#                                               176113  \
# 0  [Look, you, in, the, face,, and, it's, just, n...
#
#                                               179635  \
# 0  [I've, been, down, so, long,, it, look, like, ...
#
#                      183157  \
# 0  [They, look, up, to, me]
#
#                                               186679  \
# 0  [I, got, fake, people, showin', fake, love, to...
#
#                                               190202  \
# 0  [Straight, up, to, my, face,, straight, up, to...
#
#                                               193724  \
# 0  [I've, been, down, so, long,, it, look, like, ...
#
#                      197246  \
# 0  [They, look, up, to, me]
#
#                                               200768  \
# 0  [I, got, fake, people, showin', fake, love, to...
#
#                                               204291   207813
# 0  [Straight, up, to, my, face,, straight, up, to...  [Skrrt]
#
# [1 rows x 59 columns]

# %%
# %matplotlib inline
words_series = pd.Series(words)

words_series
# Out:
# 0          I've
# 1          been
# 2          down
# 3            so
# 4         long,
# 5            it
# 6          look
# 7          like
# 8            up
# 9            to
# 10           me
# 11         They
# 12         look
# 13           up
# 14           to
# 15           me
# 16            I
# 17          got
# 18         fake
# 19       people
# 20      showin'
# 21         fake
# 22         love
# 23           to
# 24           me
# 25     Straight
# 26           up
# 27           to
# 28           my
# 29        face,
#          ...
# 428        look
# 429        like
# 430          up
# 431          to
# 432          me
# 433        They
# 434        look
# 435          up
# 436          to
# 437          me
# 438           I
# 439         got
# 440        fake
# 441      people
# 442     showin'
# 443        fake
# 444        love
# 445          to
# 446          me
# 447    Straight
# 448          up
# 449          to
# 450          my
# 451       face,
# 452    straight
# 453          up
# 454          to
# 455          my
# 456        face
# 457       Skrrt
# dtype: object

# %%
duration/len(word_groups)
# Out:
# 3522.2542372881358

# %%
from pymongo.mongo_client import MongoClient

SPOTIPY_CLIENT_ID = "3a883c6b1fc4405ba45608df5e60e09f"
SPOTIPY_CLIENT_SECRET = "3168b907abf54925b8e482797f0eb718"

client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False

pprint.pprint(sp.search())
