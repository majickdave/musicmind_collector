# %%
import pprint
from pymongo.mongo_client import MongoClient


URI = "mongodb://MusicMind:LHBXWnYqs29lNUX6@features-shard-00-00-edm1t.mongodb.net:27017,features-shard-00-01-edm1t.mongodb.net:27017,features-shard-00-02-edm1t.mongodb.net:27017/features?ssl=true&replicaSet=features-shard-0&authSource=admin"
client = MongoClient(URI)
db = client['MetaMind']
posts = db.posts



collection = posts.find_one({'artist': 'Future', 'track': 'Mask Off'})

pprint.pprint(collection)
# Out:
# {'_id': ObjectId('58c1b1ee39affd2478e0034d'),
#  'album': 'FUTURE',
#  'artist': 'Future',
#  'artist_popularity': 93,
#  'explicit': True,
#  'feature': {'acousticness': 0.00391,
#              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rOSwuTsUlJp0Pu0MkN8r8',
#              'danceability': 0.817,
#              'duration_ms': 203963,
#              'energy': 0.418,
#              'id': '3rOSwuTsUlJp0Pu0MkN8r8',
#              'instrumentalness': 0.466,
#              'key': 2,
#              'liveness': 0.173,
#              'loudness': -9.617,
#              'mode': 1,
#              'speechiness': 0.331,
#              'tempo': 150.075,
#              'time_signature': 4,
#              'track_href': 'https://api.spotify.com/v1/tracks/3rOSwuTsUlJp0Pu0MkN8r8',
#              'type': 'audio_features',
#              'uri': 'spotify:track:3rOSwuTsUlJp0Pu0MkN8r8',
#              'valence': 0.23},
#  'featured_artists': [],
#  'followers': 2181214,
# ...

# %%
total_tracks = posts.count()

print(total_tracks, "total tracks")
# Out:
# 5621 total tracks

# %%
import pandas as pd

df =pd.DataFrame(list(posts.find()))
df
# Out:
#                            _id  \
# 0     58c1a18d39affd3e7c22a668
# 1     58c1a19c39affd3e7c22a669
# 2     58c1a1a739affd3e7c22a66a
# 3     58c1a1b339affd3e7c22a66b
# 4     58c1a1c139affd3e7c22a66c
# 5     58c1a1cf39affd3e7c22a66d
# 6     58c1a1dc39affd3e7c22a66e
# 7     58c1a1f039affd3e7c22a66f
# 8     58c1a1fb39affd3e7c22a670
# 9     58c1a20939affd3e7c22a671
# 10    58c1a21639affd3e7c22a672
# 11    58c1a22439affd3e7c22a673
# 12    58c1a23039affd3e7c22a674
# 13    58c1a23d39affd3e7c22a675
# 14    58c1a24b39affd3e7c22a676
# 15    58c1a25939affd3e7c22a677
# 16    58c1a26639affd3e7c22a678
# 17    58c1a27339affd3e7c22a679
# 18    58c1a28139affd3e7c22a67a
# 19    58c1a28f39affd3e7c22a67b
# 20    58c1a29839affd0f18ddda5e
# 21    58c1a29a39affd3e7c22a67c
# 22    58c1a2a539affd0f18ddda5f
# 23    58c1a2a939affd3e7c22a67d
# 24    58c1a2b339affd0f18ddda60
# 25    58c1a2b639affd3e7c22a67e
# 26    58c1a2be39affd0f18ddda61
# 27    58c1a2c239affd3e7c22a67f
# 28    58c1a2ca39affd0f18ddda62
# ...

# %%
print(len(df['artist'].unique()), "unique artists")
# Out:
# 775 unique artists

# %%
print(len(df['album'].unique()), "unique albums")
# Out:
# 1939 unique albums

# %%
h_count = 0
for record in df['genres']:
    if 'hip hop' in record:
        h_count+= 1
            
print(h_count, "total hiphop songs")
# Out:
# 1742 total hiphop songs

# %%
durations = []
lyrics = []

features = df['feature']

# %%
words = []
for line in df['lyrics'][456][0]:
    words.append(line.split('\n'))

# %%
duration = df.feature[0]['duration_ms']

# %%
import numpy as np

lyrics = df.lyrics[0][0][1]

words_list = lyrics.split('\n')

words_list = list(filter(('').__ne__, words_list))

for word in words_list:
    if '[' in word:
        words_list.remove(word)

# %%
words = ' '.join(words_list)
words
# Out:
# 'I\'ve been down so long, it look like up to me They look up to me I got fake people showin\' fake love to me Straight up to my face, straight up to my face I\'ve been down so long, it look like up to me They look up to me I got fake people showin\' fake love to me Straight up to my face, straight up to my face Somethin\' ain\'t right when we talkin\' Somethin\' ain\'t right when we talkin\' Look like you hidin\' your problems Really you never was solid No, you can\'t "son" me You won\'t never get to run me Just when shit look out of reach I reach back like one, three Like one, three, yeah That\'s when they smile in my face Whole time they wanna take my place Whole time they wanna take my place Whole time they wanna take my place Yeah, I know they wanna take my place I can tell that love is fake I don\'t trust a word you say How you wanna clique up after your mistakes? Look you in the face, and it\'s just not the same I\'ve been down so long, it look like up to me They look up to me 
# ...

# %%
import nltk
import matplotlib as plt
import seaborn as sns

tokens = pd.Series(nltk.word_tokenize(words))

values = tokens.value_counts()
values
# Out:
# to          32
# up          29
# ,           26
# I           25
# my          23
# me          20
# face        17
# fake        15
# look        13
# '           11
# you         10
# they        10
# wan         10
# it          10
# na          10
# like        10
# love         9
# take         8
# place        8
# straight     7
# been         7
# n't          7
# Straight     6
# down         6
# Whole        6
# people       6
# long         6
# got          6
# showin       6
# time         6
#             ..
# hidin        1
# day          1
# get          1
# Really       1
# night        1
# son          1
# safe         1
# switch       1
# tryna        1
# ''           1
# Vibe         1
# yeah         1
# of           1
# things       1
# run          1
# back         1
# changed      1
# No           1
# shit         1
# what         1
# ca           1
# Skrrt        1
# caught       1
# was          1
# away         1
# solid        1
# heard        1
# ...

# %%
timing = duration/tokens.count()
timing
# Out:
# 389.89305816135084

# %%
timing = {}

for token in tokens:
    timing[]

# %%
from pymongo.mongo_client import MongoClient

SPOTIPY_CLIENT_ID = "3a883c6b1fc4405ba45608df5e60e09f"
SPOTIPY_CLIENT_SECRET = "3168b907abf54925b8e482797f0eb718"

client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False

pprint.pprint(sp.search())
